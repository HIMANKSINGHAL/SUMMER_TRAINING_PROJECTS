# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("sales_data.csv")

# %%
df.head()
# Out:
#    order_date region   category     product  quantity  unit_price  \
# 0  2023-01-02   West   Clothing       Shoes        10      341.71
# 1  2023-01-02  South   Clothing      Jacket         8       56.53
# 2  2023-01-02  South  Groceries   Beverages         2      227.64
# 3  2023-01-04  South       Toys  Board Game         4      129.86
# 4  2023-01-05   East   Clothing      Jacket         4      201.51
#
#    discount_pct    sales  profit  customer_age  customer_satisfaction
# 0            20  3417.10  444.61            28                    3.6
# 1            10   452.24   46.26            28                    2.7
# 2             0   455.28   81.89            19                    1.7
# 3            15   519.44  127.96            64                    2.5
# 4            20   806.04  122.58            21                    1.6

# %%
df.shape
# Out:
# (405, 11)

# %%
df.tail()
# Out:
#      order_date region     category     product  quantity  unit_price  \
# 400  2023-12-26  North         Toys  Board Game         9      451.37
# 401  2023-12-26  South    Groceries       Dairy         8      155.05
# 402  2023-12-26  South    Furniture         Bed         9      364.60
# 403  2023-12-30   East    Furniture        Sofa        18       52.29
# 404  2023-12-31  South  Electronics  Headphones         9      222.51
#
#      discount_pct    sales  profit  customer_age  customer_satisfaction
# 400            20  4062.33  393.40            29                    3.2
# 401            10  1240.40  310.68            30                    1.5
# 402            15  3281.40  704.32            20                    3.4
# 403             0   941.22  165.56            53                    3.5
# 404            15  2002.59  215.29            57                    4.3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 405 entries, 0 to 404
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   order_date             405 non-null    object
#  1   region                 405 non-null    object
#  2   category               405 non-null    object
#  3   product                405 non-null    object
#  4   quantity               405 non-null    int64
#  5   unit_price             405 non-null    float64
#  6   discount_pct           405 non-null    int64
#  7   sales                  405 non-null    float64
#  8   profit                 395 non-null    float64
#  9   customer_age           405 non-null    int64
#  10  customer_satisfaction  385 non-null    float64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 34.9+ KB

# %%
df.describe()
# Out:
#          quantity  unit_price  discount_pct        sales       profit  \
# count  405.000000  405.000000    405.000000   405.000000   395.000000
# mean    10.056790  253.566173      6.950617  2533.224938   462.186152
# std      5.484834  143.137771      7.271096  2184.136414   435.595139
# min      1.000000    6.590000      0.000000    19.240000     2.770000
# 25%      5.000000  123.390000      0.000000   738.300000   131.395000
# 50%     11.000000  261.610000      5.000000  1932.320000   337.730000
# 75%     15.000000  374.140000     15.000000  3786.900000   674.965000
# max     19.000000  498.360000     20.000000  9270.670000  2430.530000
#
#        customer_age  customer_satisfaction
# count    405.000000             385.000000
# mean      43.654321               3.024675
# std       14.256456               1.155868
# min       18.000000               1.000000
# 25%       31.000000               2.000000
# 50%       43.000000               3.100000
# ...

# %%
df.dtypes
# Out:
# order_date                object
# region                    object
# category                  object
# product                   object
# quantity                   int64
# unit_price               float64
# discount_pct               int64
# sales                    float64
# profit                   float64
# customer_age               int64
# customer_satisfaction    float64
# dtype: object

# %%
df.columns.tolist()
# Out:
# ['order_date',
#  'region',
#  'category',
#  'product',
#  'quantity',
#  'unit_price',
#  'discount_pct',
#  'sales',
#  'profit',
#  'customer_age',
#  'customer_satisfaction']

# %%
df.nunique()
# Out:
# order_date               234
# region                     4
# category                   5
# product                   20
# quantity                  19
# unit_price               398
# discount_pct               5
# sales                    400
# profit                   390
# customer_age              52
# customer_satisfaction     41
# dtype: int64

# %%
df.isnull().sum()
# Out:
# order_date                0
# region                    0
# category                  0
# product                   0
# quantity                  0
# unit_price                0
# discount_pct              0
# sales                     0
# profit                   10
# customer_age              0
# customer_satisfaction    20
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(5)

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (400, 11)

# %%
df=df.dropna()

# %%
df.shape
# Out:
# (371, 11)

# %%
df["region"].head()
# Out:
# 0     West
# 1    South
# 2    South
# 3    South
# 4     East
# Name: region, dtype: object

# %%
df[["region", "category", "sales"]].head()
# Out:
#   region   category    sales
# 0   West   Clothing  3417.10
# 1  South   Clothing   452.24
# 2  South  Groceries   455.28
# 3  South       Toys   519.44
# 4   East   Clothing   806.04

# %%
df.loc[df["sales"] > 1000].head()
# Out:
#     order_date region     category product  quantity  unit_price  \
# 0   2023-01-02   West     Clothing   Shoes        10      341.71
# 5   2023-01-06   West    Furniture   Table        13      492.41
# 8   2023-01-13  South     Clothing  Jacket        19      487.93
# 9   2023-01-13  South    Groceries  Snacks        12      166.83
# 10  2023-01-14  North  Electronics  Laptop        12      119.81
#
#     discount_pct    sales   profit  customer_age  customer_satisfaction
# 0             20  3417.10   444.61            28                    3.6
# 5             10  6401.33  1084.52            37                    2.0
# 8              5  9270.67  2430.53            52                    4.2
# 9              5  2001.96   216.44            58                    4.2
# 10             5  1437.72   402.31            39                    4.5

# %%
df[(df["region"] == "North") & (df["category"] == "Electronics")].head()
# Out:
#      order_date region     category     product  quantity  unit_price  \
# 10   2023-01-14  North  Electronics      Laptop        12      119.81
# 34   2023-02-07  North  Electronics      Laptop        18      189.22
# 46   2023-02-18  North  Electronics       Phone         6      421.79
# 112  2023-04-23  North  Electronics      Laptop         9      265.89
# 123  2023-05-06  North  Electronics  Headphones         5       10.46
#
#      discount_pct    sales  profit  customer_age  customer_satisfaction
# 10              5  1437.72  402.31            39                    4.5
# 34              0  3405.96  824.84            30                    1.8
# 46              5  2530.74  603.27            63                    2.5
# 112             0  2393.01  571.87            30                    4.4
# 123            15    52.30    7.89            42                    2.7

# %%
df["region"].value_counts()
# Out:
# region
# North    103
# South    100
# East      92
# West      76
# Name: count, dtype: int64

# %%
region_code = {"North": "N", "South": "S", "East": "E", "West": "W"}
df["region_code"] = df["region"].map(region_code)
df[["region", "region_code"]].head()
# Out:
#   region region_code
# 0   West           W
# 1  South           S
# 2  South           S
# 3  South           S
# 4   East           E

# %%
region_targets = pd.DataFrame({
    "region": ["North", "South", "East", "West"],
    "sales_target": [50000, 40000, 45000, 35000]
})
df = df.merge(region_targets, on="region", how="left")
df[["region", "sales", "sales_target"]].head()
# Out:
#   region    sales  sales_target
# 0   West  3417.10         35000
# 1  South   452.24         40000
# 2  South   455.28         40000
# 3  South   519.44         40000
# 4   East   806.04         45000

# %%
print(df["order_date"].dtype)
# Out:
# object

# %%
df["order_date"] = pd.to_datetime(df["order_date"])

# %%
df["order_month"] = df["order_date"].dt.month_name()
df["profit_margin_pct"] = (df["profit"] / df["sales"] * 100).round(2)
df[["order_date", "order_month", "sales", "profit", "profit_margin_pct"]].head()
# Out:
#   order_date order_month    sales  profit  profit_margin_pct
# 0 2023-01-02     January  3417.10  444.61              13.01
# 1 2023-01-02     January   452.24   46.26              10.23
# 2 2023-01-02     January   455.28   81.89              17.99
# 3 2023-01-04     January   519.44  127.96              24.63
# 4 2023-01-05     January   806.04  122.58              15.21

# %%
monthly_sales = df.groupby(df["order_date"].dt.to_period("M"))["sales"].sum()
plt.figure(figsize=(9,5))
plt.plot(monthly_sales.index.astype(str), monthly_sales.values)
plt.xticks(rotation=45)
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.title("Monthly Sales Trend")
plt.tight_layout()
plt.show()

# %%
region_sales = df.groupby("region")["sales"].sum().sort_values(ascending=True)
plt.figure(figsize=(7,5))
plt.bar(region_sales.index, region_sales.values)
plt.xlabel("Region")
plt.ylabel("Total Sales")
plt.title("Total Sales by Region")
plt.show()

# %%
plt.figure(figsize=(7,5))
plt.hist(df["customer_age"], bins=15, edgecolor="black")
plt.xlabel("Customer Age")
plt.ylabel("Frequency")
plt.title("Distribution of Customer Age")
plt.show()

# %%
plt.figure(figsize=(7,5))
plt.scatter(df["sales"], df["profit"])
plt.xlabel("Sales")
plt.ylabel("Profit")
plt.title("Sales vs Profit")
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.histplot(df["sales"], bins=25, kde=True)
plt.title("Sales Distribution with KDE")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x="region", y="profit", data=df)
plt.title("Profit Distribution by Region")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.violinplot(x="category", y="sales", data=df)
plt.xticks(rotation=20)
plt.title("Sales Distribution by Category")
plt.show()

# %%
df.columns
# Out:
# Index(['order_date', 'region', 'category', 'product', 'quantity', 'unit_price',
#        'discount_pct', 'sales', 'profit', 'customer_age',
#        'customer_satisfaction', 'age_group', 'region_code', 'sales_target',
#        'order_month', 'profit_margin_pct'],
#       dtype='object')

# %%
plt.figure(figsize=(8,6))
num_col = df[['quantity','unit_price','discount_pct','sales','profit','customer_age','sales_target']]
sns.heatmap(num_col.corr(), annot=True)
plt.title("Correlation Heatmap")
plt.show()
